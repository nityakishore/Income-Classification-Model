# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('adult.csv')

# %%
dataset.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
dataset.shape
# Out:
# (32561, 15)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
dataset.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
dataset.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
dataset.isin(['?']).sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
dataset['income'].value_counts()
# Out:
# income
# <=50K    24720
# >50K      7841
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7, 5))
sns.histplot(dataset['income'])
plt.title('Distribution of Income')
plt.xlabel('Income')
plt.ylabel('Number of people')
plt.show()

# %%
# distribution of ages 
sns.histplot(dataset['age'], kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
education_counts = dataset['education'].value_counts()
education_counts.plot(kind='barh')
plt.xlabel('Number of People')
plt.ylabel('Education')
plt.title('Distribution of Education')
plt.gca().invert_yaxis() 
plt.show()

# %%
education_num = dataset['education.num'].value_counts()
education_num.plot(kind='bar')
plt.xlabel('Years of Education')
plt.ylabel('Number of People')
plt.title('Distribution of Years of Education')
plt.show()

# %%
marital_sts = dataset['marital.status'].value_counts()
marital_sts.plot(kind='pie')
plt.axis('off') 
plt.title('Distribution of Marital Status')
plt.show()

# %%
relationship = dataset['relationship'].value_counts()
plt.style.use('bmh')
relationship.plot(kind='pie')
plt.title('Distribution of Relationship')
centre_circle = plt.Circle((0, 0), 0.7, fc='white')
fig = plt.gcf()
plt.axis('off') 
fig.gca().add_artist(centre_circle)
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.histplot(dataset['sex'])
plt.title('Distribution of Sex')
plt.xlabel('Sex')
plt.ylabel('Number of people')
plt.show()

# %%
import squarify

# %%
race = dataset['race'].value_counts()
plt.figure(figsize=(7, 5))
squarify.plot(sizes=race, label=race.index, alpha=0.7)
plt.tick_params(labelsize=12)
plt.title('Distribution of Race') 
plt.axis('off') 
plt.show()

# %%
hours = dataset['hours.per.week'].value_counts().head(10)
plt.figure(figsize=(15, 7))
hours.plot(kind='bar')
plt.tick_params(labelsize=12)
plt.xlabel('hours per week')
plt.ylabel('Number of People')
plt.title('Distribution of Hours Per Week')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=dataset, x='age', hue='income')
plt.title('Distribution of Income across Age', fontsize=16, fontweight='bold')
plt.xlabel('Age', fontsize=12)
plt.ylabel('Number of people', fontsize=12)
plt.legend(title='Income', fontsize=10)
plt.show()

# %%
sns.countplot(x='education.num', hue='income', data=dataset)
plt.title('Income across Years of Education')
plt.xlabel('Years of Education')
plt.ylabel('Number of people')
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.countplot(x='marital.status', hue='income', data=dataset)
plt.title('Income across Years of marital status')
plt.xlabel('Marital Status')
plt.ylabel('Number of people')
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.countplot(x='race', hue='income', data=dataset)
plt.title('Income across Race')
plt.xlabel('race')
plt.ylabel('Number of people')
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.countplot(x='sex', hue='income', data=dataset)
plt.title('Income across Sex')
plt.xlabel('sex')
plt.ylabel('Number of people')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
dataset['income']=le.fit_transform(dataset['income'])

# %%
sns.pairplot(dataset, hue='income')
plt.show()

# %%
numeric_data = dataset.select_dtypes(include=[float, int])
corr = numeric_data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
dataset.replace('?', float('nan'), inplace=True)

# %%
dataset.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
column_with_NaN= ['workclass','occupation','native.country']

# %%
for col in column_with_NaN:
    most_frequent_value = dataset[col].mode()[0]
    dataset[col].fillna(most_frequent_value, inplace=True)

# %%
for col in dataset.columns:
    if dataset[col].dtypes == 'object':
        encoder = LabelEncoder()
        dataset[col] = encoder.fit_transform(dataset[col])

# %%
dataset.head()
# Out:
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   90          3   77053         11              9               6
# 1   82          3  132870         11              9               6
# 2   66          3  186061         15             10               6
# 3   54          3  140359          5              4               0
# 4   41          3  264663         15             10               5
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0           9             1     4    0             0          4356
# 1           3             1     4    0             0          4356
# 2           9             4     2    0             0          4356
# 3           6             4     4    0             0          3900
# 4           9             3     4    0             0          3900
#
#    hours.per.week  native.country  income
# 0              40              38       0
# 1              18              38       0
# ...

# %%
x= dataset.drop('income', axis=1)
y= dataset['income']

# %%
from sklearn.ensemble import ExtraTreesClassifier
selector= ExtraTreesClassifier(random_state=42)

# %%
selector.fit(x,y)
# Out:
# ExtraTreesClassifier(random_state=42)

# %%
feature_imp= selector.feature_importances_

# %%
for index, val in enumerate(feature_imp):
    print(index, round((val * 100), 2))
# Out:
# 0 15.59
# 1 4.13
# 2 16.71
# 3 3.87
# 4 8.66
# 5 8.04
# 6 7.27
# 7 8.62
# 8 1.47
# 9 2.84
# 10 8.83
# 11 2.81
# 12 9.64
# 13 1.53

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  int64
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  int64
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  int64
#  6   occupation      32561 non-null  int64
#  7   relationship    32561 non-null  int64
#  8   race            32561 non-null  int64
#  9   sex             32561 non-null  int64
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  int64
# dtypes: int64(14)
# memory usage: 3.5 MB

# %%
x= x.drop(['workclass', 'education', 'race', 'sex','capital.loss', 'native.country'], axis=1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
for col in x.columns:
    scaler = StandardScaler()
    x[col] = scaler.fit_transform(x[col].values.reshape(-1, 1))

# %%
round(y.value_counts(normalize=True)*100,2).astype('str')+'%'
# Out:
# income
# 0    75.92%
# 1    24.08%
# Name: proportion, dtype: object

# %%
# !pip install -U imbalanced-learn
# Out:
# Requirement already up-to-date: imbalanced-learn in /home/nitya/.local/lib/python3.8/site-packages (0.12.3)
# ...

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)

# %%
ros.fit(x,y)
# Out:
# RandomOverSampler(random_state=42)

# %%
x_reshaped, y_reshaped = ros.fit_resample(x,y)

# %%
round(y_reshaped.value_counts(normalize=True)*100,2).astype('str')+'%'
# Out:
# income
# 0    50.0%
# 1    50.0%
# Name: proportion, dtype: object

# %%
#creating a train test spilt 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x_reshaped, y_reshaped, test_size=0.2, random_state=42)

# %%
print("X_train shape:", x_train.shape)
print("X_test shape:", x_test.shape)
print("Y_train shape:", y_train.shape)
print("Y_test shape:", y_test.shape)
# Out:
# X_train shape: (39552, 8)
# X_test shape: (9888, 8)
# Y_train shape: (39552,)
# Y_test shape: (9888,)

# %%
#data modeling: logistic regression
from sklearn.linear_model import LogisticRegression
lg= LogisticRegression(random_state=42)
lg.fit(x_train,y_train)
y_pred_lg= lg.predict(x_test)

# %%
#data modeling: KNN Classifier
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred_knn= knn.predict(x_test)

# %%
#data modeling: support vector classifier
from sklearn.svm import SVC
svc= SVC(random_state=42)
svc.fit(x_train, y_train)
y_pred_svc= svc.predict(x_test)

# %%
#data modeling: naive bayes classifier 
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(x_train,y_train)
y_pred_nb= nb.predict(x_test)

# %%
#data modeling: decision tree classifier
from sklearn.tree import DecisionTreeClassifier
dt= DecisionTreeClassifier(random_state=42)
dt.fit(x_train, y_train)
y_pred_dt= dt.predict(x_test)

# %%
#data modeling: random forest classifier
from sklearn.ensemble import RandomForestClassifier
rf= RandomForestClassifier(random_state=42)
rf.fit(x_train,y_train)
rf_pred_rf=rf.predict(x_test)

# %%
#data modeling: XGB Classifier
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(x_train, y_train)
y_pred_xgb = xgb.predict(x_test)

# %%
# Model Evaluation
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

print('Logistic Regression:')
print('Accuracy score:', round(accuracy_score(y_test, y_pred_lg) * 100, 2))
print('F1 score:', round(f1_score(y_test, y_pred_lg) * 100, 2))
# Out:
# Logistic Regression:
# Accuracy score: 75.25
# F1 score: 75.08

# %%
print('KNN Classifier:')
print('Accuracy score:', round(accuracy_score(y_test, y_pred_knn) * 100, 2))
print('F1 score:', round(f1_score(y_test, y_pred_knn) * 100, 2))
# Out:
# KNN Classifier:
# Accuracy score: 83.42
# F1 score: 84.43

# %%
print('Support Vector Classifier:')
print('Accuracy score:', round(accuracy_score(y_test, y_pred_svc) * 100, 2))
print('F1 score:', round(f1_score(y_test, y_pred_svc) * 100, 2))
# Out:
# Support Vector Classifier:
# Accuracy score: 81.58
# F1 score: 82.56

# %%
print('Naive Bayes Classifier:')
print('Accuracy score:', round(accuracy_score(y_test, y_pred_nb) * 100, 2))
print('F1 score:', round(f1_score(y_test, y_pred_nb) * 100, 2))
# Out:
# Naive Bayes Classifier:
# Accuracy score: 64.68
# F1 score: 48.42

# %%
print('Decision Tree Classifier:')
print('Accuracy score:', round(accuracy_score(y_test, y_pred_dt) * 100, 2))
print('F1 score:', round(f1_score(y_test, y_pred_dt) * 100, 2))
# Out:
# Decision Tree Classifier:
# Accuracy score: 91.61
# F1 score: 92.01

# %%
print('Random Forest Classifier:')
print('Accuracy score:', round(accuracy_score(y_test, rf_pred_rf) * 100, 2))
print('F1 score:', round(f1_score(y_test, rf_pred_rf) * 100, 2))
# Out:
# Random Forest Classifier:
# Accuracy score: 92.6
# F1 score: 92.93

# %%
print('XGB Classifier:')
print('Accuracy score:', round(accuracy_score(y_test, y_pred_xgb) * 100, 2))
print('F1 score:', round(f1_score(y_test, y_pred_xgb) * 100, 2))
# Out:
# XGB Classifier:
# Accuracy score: 86.07
# F1 score: 86.61

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = np.linspace(40, 150, 15).astype(int).tolist()
max_depth = np.linspace(40, 150, 15).astype(int).tolist()

# %%
param_dist = {
    'n_estimators':n_estimators,
    'max_depth':max_depth,
}

# %%
rf_tuned = RandomForestClassifier(random_state=42)

# %%
rf_cv= RandomizedSearchCV(rf_tuned, param_dist, cv=5, random_state=42)

# %%
rf_cv.fit(x_train, y_train)

# %%
rf_cv.best_score_

# %%
rf_cv.best_params_
# Out:
# {'n_estimators': 40, 'max_depth': 102}

# %%
rf_best= RandomForestClassifier(max_depth=120, n_estimators=40, random_state=42)

# %%
rf_best.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=120, n_estimators=40, random_state=42)

# %%
y_pred_rf_best= rf_best.predict(x_test)

# %%
print('Random Forest Classifier:')
print('Accuracy score:', round(accuracy_score(y_test, y_pred_rf_best) * 100, 2))
print('F1 score:', round(f1_score(y_test, y_pred_rf_best) * 100, 2))
# Out:
# Random Forest Classifier:
# Accuracy score: 92.77
# F1 score: 93.08

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test, y_pred_rf_best)

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='magma')
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_rf_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92      4955
#            1       0.89      0.98      0.93      4933
#
#     accuracy                           0.93      9888
#    macro avg       0.93      0.93      0.93      9888
# weighted avg       0.93      0.93      0.93      9888
